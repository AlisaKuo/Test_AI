# %%
#自訂class
class Person:
    def __init__(self):
        self.name = "robert"    #建立name屬性
        self.age = 25           #建立age屬性

# %%
p1 = Person()
#print(type(p1))
print(p1.name)
print(p1.age)
# Out:
# robert
# 25

# %%
p2 = Person()
print(p2.name)
print(p2.age)
# Out:
# robert
# 25
