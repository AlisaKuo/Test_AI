# %%
#猜數字遊戲

import random

min=1   #設定一個參數對日後修改程式碼比較方便
max=100
count=0
N = random.randint(min,max)
print("======猜數字遊戲======:\n")

while(True):
  count+=1
  keyin = int(input(f"猜數字範圍{min}~{max}:"))
  if keyin >= min and keyin <= max:
    if keyin == N:
      print(f"Bingo! 答案是{N}")
    else:
      print("在範圍內")
  else:
    print ("不在範圍內")
    break

print ("遊戲結束")
# Out:
# ======猜數字遊戲======:
#
# 在範圍內
# 不在範圍內
# 遊戲結束

# %%
#猜數字遊戲

import random

min= 1   #設定一個參數對日後修改程式碼比較方便
max= 100
count= 0

N = random.randint(min,max)
print("======猜數字遊戲======:\n")

while(True):
  count+=1
  keyin = int(input(f"猜數字範圍{min}~{max}:"))
  if keyin >= min and keyin <= max:
     if keyin == N:
        print(f"Bingo! 答案是{N}")
        print(f"總共猜了{count}次")
        break
     elif keyin > N:
        print("要小一點")
        max = keyin-1
     elif keyin < N:
        print("要大一點")
        min = keyin+1
      print (f"已經猜了{count}次")
   else:
      print ("不在範圍內")

print ("遊戲結束")
# Out:
# ======猜數字遊戲======:
#
# 要小一點
# 已經猜了1次
# 要大一點
# 已經猜了2次
# 要小一點
# 已經猜了3次
# Bingo! 答案是13
# 總共猜了4次
# 遊戲結束

# %%
#猜數字遊戲

import random

while(True):
    min= 1   #設定一個參數對日後修改程式碼比較方便
    max= 100
    count= 0
    answer = random.randint(min,max)
    #print(answer)
    print("==========猜數字遊戲==========:\n")

    while(True):
        count+=1
        guess = int(input(f"猜數字範圍{min}~{max}:"))
        if guess >= min and guess <= max:
            if guess == answer:
                print(f"Bingo! 答案是{answer}")
                print(f"總共猜了{count}次")
                break
            elif guess > answer:
                print("要小一點")
                max = guess-1
            elif guess < answer:
                print("要大一點")
                min = guess+1
            print (f"已經猜了{count}次")
        else:
            print ("不在範圍內")
        
    play_again= input("還要繼續玩嗎? (y,n)?")
    if play_again == "n":
        break

print ("遊戲結束")
# Out:
# 4
# ======猜數字遊戲======:
#
# 要小一點
# 已經猜了1次
# 要小一點
# 已經猜了2次
# 要大一點
# 已經猜了3次
# 要小一點
# 已經猜了4次
# Bingo! 答案是4
# 總共猜了5次
# 遊戲結束

# %%
import random

def play_game():    #自訂 function
    min= 1          #設定一個參數對日後修改程式碼比較方便
    max= 100
    count= 0
    answer = random.randint(min,max)
    #print(answer)
    print("==========猜數字遊戲==========\n")

    while(True):
        count+=1
        guess = int(input(f"猜數字範圍{min}~{max}:"))
        if guess >= min and guess <= max:
            if guess == answer:
                print(f"Bingo! 答案是{answer}")
                print(f"總共猜了{count}次")
                break
            elif guess > answer:
                print("要小一點")
                max = guess-1
            elif guess < answer:
                print("要大一點")
                min = guess+1
            print (f"已經猜了{count}次")
        else:
            print ("不在範圍內")

while(True):        #主程式區
    
    play_game()
    play_again= input("還要繼續玩嗎? (y,n)?")
    if play_again == "n":
        break
print ("遊戲結束")
# Out:
# ==========猜數字遊戲==========
#
# 要小一點
# 已經猜了1次
# Bingo! 答案是10
# 總共猜了2次
# 遊戲結束
