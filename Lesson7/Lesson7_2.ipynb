# %%
cities=[]    #建立一個沒有元素的list

#使用list的實體方法append()
cities.append("台北")
print(cities)
cities.append("台中")
print(cities)
cities.append("台南")
print(cities)
cities.append("高雄")
print(cities)
# Out:
# ['台北']
# ['台北', '台中']
# ['台北', '台中', '台南']
# ['台北', '台中', '台南', '高雄']

# %%
cities.insert(0,"基隆")   #插入元素
print(cities)
cities.clear()   #清空陣列
print(cities)
# Out:
# ['基隆', '台北', '台中', '台南', '高雄']
# []
