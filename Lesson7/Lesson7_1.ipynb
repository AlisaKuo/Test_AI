# %%
city1 = "台北"
city2 = "台中"
city3 = "高雄"
print (city1)
print (city2)
print (city3)
# Out:
# 台北
# 台中
# 高雄

# %%
#[]建立list
cities = ["台北", "台中","高雄"]
print (cities)
print (cities[0])
print (cities[1])
print (cities[2])
#print (cities[3]) --> index error
# Out:
# ['台北', '台中', '高雄']
# 台北
# 台中
# 高雄

# %%
greetings = ["H","e","l","l","o","","w","o","r","l","d"]

# %%
#[]建立list實體
greetings = list("Hello World!")
print(type(greetings))
print(greetings)
print(greetings[0])
# Out:
# <class 'list'>
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd', '!']
# H
