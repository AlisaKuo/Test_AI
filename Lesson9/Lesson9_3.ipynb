# %%
numbers:list[int]=[1,3,5,7,9]
weeks:list[str]=["monday","tuesday","wednesday","thursday","friday"]

# %%
print(type(weeks))
# Out:
# <class 'list'>

# %%
for week in weeks:
    print(week)
# Out:
# monday
# tuesday
# wednesday
# thursday
# friday

# %%
#slice
#weeks[0:3]
weeks[-3:]
# Out:
# ['monday', 'tuesday', 'wednesday']

# %%
#[1,3,5,7,9]
#傳統方法建立
nums=[]
for i in range (1,10):
    if i % 2 == 1:
        nums.append(i)
nums
# Out:
# [1, 3, 5, 7, 9]

# %%
#使用list的comprehesion建立

print([i for i in range (1,10)])
print ([i for i in range (1,10) if i % 2 == 1])
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [1, 3, 5, 7, 9]

# %%
# dict的comprehension
word = "letters"
print({letter:word.count(letter) for letter in word})
print({letter:word.count(letter) for letter in word if letter=="e"})
# Out:
# {'l': 1, 'e': 2, 't': 2, 'r': 1, 's': 1}
# {'e': 2}

# %%
#錯誤和例外實體
raise NameError("名字錯誤")
raise TypeError("型別錯誤")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 #錯誤和例外實體
# ----> 2 raise NameError("名字錯誤")
#       3 raise TypeError("型別錯誤")
#
# NameError: 名字錯誤
